# %%
import requests
import json
import os
	
# base url for specific api
base_url = 'https://api.open.fec.gov/v1/'
	
# operation to execute for the api
operation = 'candidates'
	
# get key from environment variable
key = '6I7afAohGvZsQb0L3TXcHS5xeClSR12cU6qPccG4'

api_parameters = {'api_key': key, 'office':'H', 'sort':'name', 'state':'CA', 'election_year':[2016]}
candidates = requests.get(base_url + operation,  params = api_parameters).json()
num_pages = candidates['pagination']['pages']

    
for page in range(2, num_pages+1):
    # additional api parameters specific to the operation
    api_parameters = {'api_key': key, 'office':'H', 'sort':'name', 'state':'CA', 'election_year':[2016], 'page': page}

    # ping api
    response = requests.get(base_url + operation, params = api_parameters)

    # print status code and load returned data into json
    print('Response Code: {0}\n'.format(response.status_code))
    data = json.loads(response.text)

    # save raw data
    with open('fec_api_results.json', 'a') as outfile:
        json.dump(data, outfile)

    # loop through results and print name
    for candidate in data['results']:
        print(candidate['name'])
# Out:
# Response Code: 200
#
# BERA, AMERISH
# BERNAL, BENITO BENNY
# BOMBERGER, JEFFREY
# BRANCA, ALBERT JAMES MR.
# BRANDMAN, JORDAN
# BROWNLEY, JULIA
# BRUNER, MATTHEW
# CAFFREY, ANDY
# CAFORIO, BRYAN
# CALVERT, KEN
# CAMPOS, LOUIE J
# CANADA, MIKE
# CAPPS, LOIS G
# CARBAJAL, SALUD O.
# CARDENAS, ANGEL
# CARDENAS, TONY
# CARO, SUZANNE M
# CASTILLO, CHRISTOPHER
# CHABOT, PAUL R DR.
# CHEADLE, GREGORY
# Response Code: 200
#
# CHU, JUDY
# CLEEK, N EUGENE MD
# COHEN, RONALD H
# CONDLEY, KERRI
# CONTRERAS, LOUIE A
# COOK, PAUL
# CORREA, LOU
# COSTA, JIM MR.
# DAGNESSES, RAFAEL
# DAVIDSON, STIEVEN LEE MR
# DAVIS, LUKE
# DAVIS, SUSAN A.
# DELGADILLO, MARTHA C.
# DE MAURICIO, MICHAEL
# DENHAM, JEFF
# DERLET, ROBERT WAYNE
# DESAULNIER, MARK
# DETERT, RYAN
# DIGBY, JACK
# DONNELLY, TIM
# Response Code: 200
#
# DOWNING, RYAN
# DUNN, JOSEPH
# EDWARDS, ADRIENNE
# EGGMAN, MICHAEL RAY
# ESHOO, ANNA G
# ESTRADA, LUIS CARLOS MR.
# EVANS, ROBERT S
# FAREED, JUSTIN
# FARR, SAM
# FISCHELLA, TYLER R
# FISHER, GORDAN E.
# FLYNN, SEAN
# FOX, RANDY
# FOX, RICHARD B
# GALVAN, MARIO
# GAMBLE , VENICE JAYMES II
# GAONA, RODOLFO RUDY
# GARAMENDI, JOHN
# GENOVESE, SAL
# GERLACH, JEFFREY D
# Response Code: 200
#
# GIBSON, CHARLOTTE DIANE
# GITSHAM, DENISE
# GONZALEZ, ROMAN GABRIEL
# GOURON, MAX M.D.
# GRAY, CASEY LOGSDON
# GRIFFIN, MORRIS F
# GUTZEIT, MARIA
# GUZMAN, DAVID
# HAHN, JANICE
# HALL, ISADORE III
# HARLOW, BOB
# HASAN, SHARIFF M
# HERMANSON, BARRY
# HERNANDEZ, ROGER
# HIDALGO, JUAN M JR
# HODGES, ROBERT L
# HONDA, MIKE
# HONEGGER, BARBARA
# HORST, JOHN H
# HUERTA, EMILIO J. MR.
# Response Code: 200
#
# HUFFMAN, JARED
# HUNTER, DUNCAN D
# ISAKSON, STEVE WESLEY PHD
# ISSA, DARRELL
# JEFFERSON, DELMA
# JONES, SCOTT
# JOYA, ANALILIA
# KAHN, SANFORD W
# KEALY, DWIGHT
# KHANNA, ROHIT
# KNIGHT, STEVE
# KOKKONEN, MATT
# KUO, PETER
# LAMALFA, DOUG
# LANCASTER, GORDON K CA
# LAPLANTE, ROGER ALAN
# LAUTEN, ROBERT EDMUND
# LEE, BARBARA
# LIEU, TED
# LOFGREN, ZOE
# Response Code: 200
#
# LOWENTHAL, ALAN
# LUCAS, BENJAMIN
# LUCIUS, CASEY
# MALLOY, JEFFREY
# MARIN, NANCY TRINIDAD
# MATSUI, DORIS
# MCCARTHY, KEVIN
# MCCLINTOCK, THOMAS
# MCNERNEY, JERRY
# MEISTERLIN, SCOTT C
# MEJIA, KENNETH
# MENDOZA, MATTHEW JAMES
# MENSING, DALE KENNETH
# MERCADO, JUAN
# METTLER, KEN
# MILLER, ROBERT
# MOFFATT, JEFFREY
# MONTES, JOSEPH
# MORRIS, GERALD A
# MURDOCK, BRETT
# Response Code: 200
#
# MUSANTE, MARCUS
# NANCE, KATHRYN D
# NAPOLITANO, GRACE
# NAVARRO, OMAR
# NGUYEN, BAO QUOC
# NUNES, DEVIN G.
# OLIVERIO, PIERLUIGI
# ORSWELL, JACK
# ORTIZ, SYLVIA
# ORTON, WILLIAM R. "BILL"
# OSHINS, JEFF
# OSTRANDER, WILLIAM
# OXLEY, GARY ALLEN
# PALSSON, NILS IAN
# PANETTA, JIMMY
# PARRA, DANIEL
# PATRICK, PATREA
# PELOSI, NANCY
# PEREZ, CONNIE
# PETERSEN, ROGER
# Response Code: 200
#
# PETERSON, BOB
# PETERSON, DAVID
# PETERS, SCOTT
# PICUS, PRESTON
# PINKERTON, JOHN
# POLING, ALEX
# POWELL, MARK EDWARD
# RAB, AEJAZ (RAJI)
# RAMIREZ-DEAN, RITA DR
# RATHS, GREGORY GERARD
# REED, JAMES E
# REED, MARK
# REED, WENDY
# ROGERS, DAVID BRYAN
# ROHRABACHER, DANA
# ROYBAL-ALLARD, LUCILLE
# ROYCE, ED MR.
# RUBIO, MICHAEL
# RUIZ, RAUL DR.
# RYAN, CODY
# Response Code: 200
#
# SANCHEZ, CARLOS J MR
# SANCHEZ, HEBERTO M
# SANCHEZ, LINDA
# SANCHEZ, LORETTA
# SANTAMARIA, CARLOS J
# SANTIAGO, ALBERTO ZUNIGA
# SAVARY, SUZANNE JOYCE
# SCHIFF, ADAM
# SCHNEIDER, HELENE
# SCHOTT, LYNN
# SCHRODE, ERIN AZARIA
# SECOR, DAVID B
# SERETSKIY, YURIY
# SHAMMAS, JOSEPH IVARO
# SHEPHERD, DOUG
# SHERIDAN, TIMOTHY J
# SHERMAN, BRAD
# SHIOURA, FUJI H.
# SIEGEL, RONALD
# SILVA, ROBERT LEO II MA
# Response Code: 200
#
# SIMON, FRED J JR MD
# SINGH, NAVRAJ
# SOLIS, LENORE
# SOTOMAYOR, ARMANDO
# SPEARS, LINDA MARIMARIE AKA "WHITEFEAT
# SPEIER, JACKIE
# STONE, JEFFREY E
# SWALWELL, ERIC MICHAEL
# SWEENEY, TIM
# TACHERRA, JOHNNY
# TAKANO, MARK
# THOMAS, EVAN CHARLES
# THOMPSON, KIRK WAYNE
# THOMPSON, MIKE MR.
# TORRES, NORMA
# TOWNSEND, CHRISTOPHER DAVID
# TURNER, DANNY REID
# UEBERSAX, JOHN
# VALADAO, DAVID
# VARASTEH, RON
# Response Code: 200
#
# VARGAS, JUAN C.
# VELTMEYER, JAMES
# VINCE, LOU
# WALPERT, NICHOLAS "NICK"
# WALTERS, MIMI
# WATERS, MAXINE
# WATSON, KENNITA
# WATSON, LUPE RAMOS
# WHALLON, ANDREW
# WHITEHEAD, PAUL
# WHITE, JEFFERY SAALIK
# WHITE, SEAN
# WIGGINS, CHRISTOPHER BLAKE
# WILLIAMS, JOE
# WINGO , RYAN GLENN
# WOLKOWICZ, STEPHAN "STEVEN"
# WOOKEY, MATTHEW ROBERT
# WRIGHT, DOUGLAS A.
# WRIGHT, KENNETH
